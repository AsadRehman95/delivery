# %%
# prompt: import pandas as pd

import pandas as pd

# %%
# prompt: import /content/Asad Rehman - revolutioncart_data.csv

df = pd.read_csv('/content/Asad Rehman - revolutioncart_data.csv')

# %%
# prompt: df

df
# Out:
#     month_of_year  is_holiday_season  total_sku_count  average_product_rating  \
# 0               1                  0      12440.14782                3.852202
# 1               2                  0      12287.09708                3.913549
# 2               3                  0      13554.97763                4.196981
# 3               4                  0      14912.24666                4.079651
# 4               5                  0      13636.99114                3.907948
# ..            ...                ...              ...                     ...
# 79              8                  0      48028.15391                3.849764
# 80              9                  0      50277.97865                4.206576
# 81             10                  0      51336.69082                4.096457
# 82             11                  1      52939.40000                4.178313
# 83             12                  1      51425.16345                4.393259
#
#     new_product_releases  total_customers  new_customers  \
# 0              84.081933      47489.64585    5160.112499
# 1              93.081933      56251.30704    4969.480662
# 2             115.081933      90817.67539    5090.886626
# 3             109.081933      97996.56709    5001.438910
# 4             102.081933     107164.51180    5144.330734
# ..                   ...              ...            ...
# 79             97.081933     914646.13160    4896.343635
# 80            116.081933     920519.04450    4872.669622
# 81             95.081933     942091.57200    4885.167906
# 82            123.081933     936030.24190    4860.009036
# 83            104.081933     956126.02480    5132.112499
#
#     customer_retention_rate  average_page_load_time  \
# 0                  0.700150                2.608194
# 1                  0.688037                2.286818
# 2                  0.754210                3.525832
# 3                  0.708542                3.150905
# 4                  0.712701                2.469266
# ..                      ...                     ...
# 79                 0.750530                3.313814
# 80                 0.611198                3.095429
# 81                 0.772298                3.665897
# 82                 0.687920                3.171360
# 83                 0.674477                3.189397
#
#     mobile_traffic_percentage  marketing_spend  email_campaign_clicks  \
# 0                   29.058984       511.429142            49856.56623
# 1                   30.154245       465.885008            50223.56623
# 2                   31.365668       479.025109            50277.56623
# 3                   27.811655       502.584885            50151.56623
# 4                   29.017549       570.747323            50143.56623
# ..                        ...              ...                    ...
# 79                  69.221499       408.749619            49841.56623
# 80                  68.397062       422.405735            50305.56623
# 81                  68.881866       578.884963            49784.56623
# 82                  71.180849       557.114784            50116.56623
# 83                  68.754119       686.487797            50048.56623
#
#     social_media_engagement  average_shipping_time  return_rate  \
# 0               99761.50674               3.172891    10.110812
# 1              100987.33900               3.778945     8.527737
# 2              102840.02460               3.542102     9.830225
# 3              104988.90820               2.297694     9.037544
# 4              106271.30130               2.588130     9.205921
# ..                      ...                    ...          ...
# 79              94224.49718               3.055060    11.132098
# 80              95322.51064               3.362108    10.891006
# 81              96913.12322               3.120947     8.456553
# 82              98536.12846               3.352322     7.387530
# 83              99859.50674               2.622607    10.875771
#
#     customer_support_tickets  competitor_price_index  \
# 0                1942.925744               96.840646
# 1                1994.925744              112.390933
# 2                1983.925744               96.778699
# 3                2048.925744              100.522693
# 4                2037.925744              107.310486
# ..                       ...                     ...
# 79               1993.925744               96.954673
# 80               2063.925744              103.571260
# 81               1986.925744               93.328490
# 82               2026.925744              101.067726
# 83               2015.925744               92.817028
#
#     consumer_confidence_index  monthly_revenue
# 0                  103.301295      150622.6142
# 1                   98.280580      178125.3643
# 2                   82.485677      204916.8175
# 3                  110.284389      195806.4177
# 4                   91.291079      189544.5679
# ..                        ...              ...
# 79                  95.105332      226527.9955
# 80                 102.021833      253095.1575
# 81                  95.682981      250467.2965
# 82                 100.321605      292421.4396
# 83                 111.812970      303652.0427
#
# [84 rows x 19 columns]

# %%
# prompt: consider monthly_revenue as Y and all other as x

X = df.drop('monthly_revenue', axis=1)
Y = df['monthly_revenue']

# %%
# prompt: split data into test and train

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# prompt: generate lasso regression model for x and Y train

from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.1)  # You can adjust the alpha value
lasso_model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.467e+08, tolerance: 5.508e+06
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %%
# prompt: do cross validation

from sklearn.model_selection import cross_val_score

# Perform cross-validation (e.g., 5-fold)
cv_scores = cross_val_score(lasso_model, X_train, Y_train, cv=5)

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.9580169  0.96252323 0.95333699 0.94909022 0.89863374]
# Average cross-validation score: 0.94432021318324
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.114e+08, tolerance: 4.567e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.660e+08, tolerance: 3.976e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.728e+08, tolerance: 4.259e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.693e+08, tolerance: 4.436e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.063e+08, tolerance: 4.761e+06
#   model = cd_fast.enet_coordinate_descent(

# %%
# prompt: dump model

import pickle

# Save the trained model to a file
filename = 'lasso_model.sav'
pickle.dump(lasso_model, open(filename, 'wb'))

# %%
# prompt: create streamlit app for the model

# %%writefile app.py
import streamlit as st
import pandas as pd
import pickle

# Load the trained Lasso model
filename = 'lasso_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# Create a Streamlit app
st.title("Monthly Revenue Prediction App")

# Input features for prediction
st.header("Enter Input Features:")

# Get input values from user
website_traffic = st.number_input("Website Traffic", min_value=0)
marketing_spend = st.number_input("Marketing Spend", min_value=0)
customer_acquisition_cost = st.number_input("Customer Acquisition Cost", min_value=0)
average_order_value = st.number_input("Average Order Value", min_value=0)
conversion_rate = st.number_input("Conversion Rate", min_value=0.0, max_value=1.0, step=0.01)

# Create a button to trigger prediction
if st.button("Predict Monthly Revenue"):
    # Create a DataFrame with user input
    input_data = pd.DataFrame({
        'website_traffic': [website_traffic],
        'marketing_spend': [marketing_spend],
        'customer_acquisition_cost': [customer_acquisition_cost],
        'average_order_value': [average_order_value],
        'conversion_rate': [conversion_rate]
    })

    # Make the prediction
    predicted_revenue = loaded_model.predict(input_data)[0]

    # Display the predicted revenue
    st.header("Predicted Monthly Revenue:")
    st.write(f"{predicted_revenue:.2f}")
# Out:
# Writing app.py
